# %%
# %matplotlib inline
# %run LEDSweep.py
# Out:
# Enter Manufacturer Wavelength in nm :742
# Enter Full Product Code:1125-1084-ND
# Enter Number of Sweeps Completed in integers:3
# Please Enter Boxcar Value :6
#
# The filename is 742nm_1125-1084-ND_sweeps3_boxcar6_.xlsx
# RMSE: 0.06782976392342488
# R-squared: 0.9534022062047899
#
# RMSE: 0.05876617000279105
# R-squared: 0.9561657536591691
#
# RMSE: 0.05861302332167364
# R-squared: 0.9565685690283044
#
# RMSE: 0.07686515908184116
# R-squared: 0.9323268812316405
#
# Cannot achieve desired accuracy given boundaries specified
# Either increase length of boundary specification or decrease desired accuracy
# Model Variables
# 	   g1 		   g2 		   g3
# 1. 	 1.000e+00 	 0.000e+00 	 1.000e+01
# 2. 	 4.444e-02 	 1.000e+01 	 5.000e+01
# 3. 	 2.222e-02 	 1.000e+01 	 1.000e+01
# 4. 	 1.333e-01 	 1.000e+01 	 1.000e+01
# RMSE: 0.09521529968702747
# R-squared: 0.8850636823821462
#
# RMSE: 0.09390602297293699
# R-squared: 0.8899441259146228
#
# RMSE: 0.08674328514729371
# ...

# %%
df = Database_Update.Table_Search()
# Out:
# Enter Manufacturer Wavelength in nm :742
# Enter Full Product Code :1125-1084-ND

# %%
df
# Out:
#          date      time  product_code wavelength                 model  \
# 1  2019-07-05  14:30:49  1125-1084-ND      742nm  Gaussian Power Model
#
#        rmse                                             param1  \
# 1  0.076865  {1.0,0.044444444444444446,0.022222222222222223...
#
#                  param2                 param3 param4  \
# 1  {0.0,10.0,10.0,10.0}  {10.0,50.0,10.0,10.0}     {}
#
#                                     normalized_power
# 1  {0.004449097095001071,0.0014830323650002778,0....
