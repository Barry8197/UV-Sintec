# %%
# %matplotlib inline
# %run LEDSweep.py
# Out:
# Enter Manufacturer Wavelength in nm :810
# Enter Full Product Code:2
# Enter Number of Sweeps Completed in integers:1
# Please Enter Boxcar Value :1
#
# The filename is 810nm_2_sweeps1_boxcar1_.xlsx
#
# Please Enter Angle of LED:0
# Peak Indices/Index:  [194 236]
# Please Enter Angle of LED:0
# Peak Indices/Index:  [238]
# Please Enter Angle of LED:0
# Peak Indices/Index:  [208 250]
# Please Enter Angle of LED:0
# Peak Indices/Index:  [194 236]
# RMSE: 0.0998987199382925
# R-squared: 0.80193718426031
#
# RMSE: 0.09792759308774841
# R-squared: 0.8111764299224569
#
# RMSE: 0.09792759308774841
# R-squared: 0.8111764299224569
#
# RMSE: 0.11515462087207796
# R-squared: 0.7686197895065771
#
# Cannot achieve desired accuracy given boundaries specified
# Either increase length of boundary specification or decrease desired accuracy
# Model Variables
# 	   g1 		   g2 		   g3
# 1. 	 7.717e-01 	 0.000e+00 	 1.439e+01
# 2. 	 4.444e-02 	 5.000e+01 	 2.000e+01
# 3. 	 0.000e+00 	 0.000e+00 	 0.000e+00
# 4. 	 1.556e-01 	 1.000e+01 	 2.000e+01
# RMSE: 0.09897769473347184
# R-squared: 0.8065490323610347
#
# RMSE: 0.09680152200358852
# R-squared: 0.8129014427911423
#
# RMSE: 0.09644957844023193
# R-squared: 0.814771432729881
#
# RMSE: 0.11029063181620923
# R-squared: 0.7816879307183852
#
# Cannot achieve desired accuracy given boundaries specified
# Either increase length of boundary specification or decrease desired accuracy
# Model Variables
# 	   c1 		   c2 		   c3
# 1. 	 7.550e-01 	 0.000e+00 	 2.132e+01
# 2. 	 4.444e-02 	 4.500e+01 	 2.222e+01
# 3. 	 2.222e-02 	 2.500e+01 	 2.000e+02
# 4. 	 1.556e-01 	 1.000e+01 	 2.222e+01
# RMSE: 0.11029063181620923
# R-squared: 0.7816879307183852
#
# RMSE: 0.11515462087207796
# R-squared: 0.7686197895065771
#
# The optimal RMSE is:
# 0.11029063181620923

# %%
import Database_Update
import matplotlib.pyplot as plt

# %%
Database_Update.Database_Search()
# Out:
# interactive(children=(Text(value='', description='Input:', placeholder='Enter Product Code'), Output()), _dom_…

# %%
power = Database_Update.Data_Extract()
try :
    plt.plot(power)
except :
    pass

# %%
Database_Update.Row_Delete()
